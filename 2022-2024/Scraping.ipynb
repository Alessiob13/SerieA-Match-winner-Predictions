# %% [markdown]
# # SCRAPING SERIE A

# %% [markdown]
# ### Questa progetto consiste nel raccogliere ed analizzare i dati relativi al campionato di serie A, predicendo in seguito, attraverso un algoritmo di machine learning, la probabile vincitrice di ogni partita. I dati raccolti vanno dalla stagione 2022-2023 alla stagione 2023-2024, giornata 30, ovvero la giornata in cui è stata fatta l'analisi.

# %%
import requests

# %%
#url alla pagina che contiene tutte le statistiche dei campionati. in particolare
#ci concentriamo sulle statistiche di serie A, prenderemo le statistiche di ogni squadra
#che vanno dall'anno 2020 alla giornata 15 della stagione 2023, giornata in cui
# stiamo facendo questa analisi

standings_url = "https://fbref.com/it/comp/11/Statistiche-di-Serie-A"

# %%
data = requests.get(standings_url)

# %%
#Ci interessa ottenere gli url di ogni squadra. Quindi dall'url delle statistiche di serie A
#prenderemo gli url di ogni squadra da questa pagina, che conterranno le informazioni
#utili per ogni squadra. Per farlo utilizzeremo l'ispezione della sorgente della pagina,cosi
#da trovare l'url che ci interessa.per farlo utilizziamo la libreria Beautfoul Soup

# %%
from bs4 import BeautifulSoup

# %%
soup = BeautifulSoup(data.text)

# %%
#ci interessa selezionare la tabella, utilizzando il tag dalla sorgente
standings_table = soup.select('table.stats_table')[0] #css selector

# %%
#adesso ci interessa trovare i link da questa tabella, ovvero i tags "a"

links = standings_table.find_all('a')

#cerchiamo la proprietà 'href' per ogni link
links = [l.get("href") for l in links]

# %%
# Adesso facciamo un controllo sui link, sostanzialmente controlliamo se il parametro
# '/squadre/' è nel link, se non lo è ci sbarazziamo del link poichè non ci interessa.
# In questo modo otteniamo i link a tutte le squadre partecipanti al campionato
links = [l for l in links if "/squadre/" in l]

links
# Out:
# ['/it/squadre/d609edc0/Statistiche-Internazionale',
#  '/it/squadre/dc56fe14/Statistiche-Milan',
#  '/it/squadre/e0652b02/Statistiche-Juventus',
#  '/it/squadre/1d8099f8/Statistiche-Bologna',
#  '/it/squadre/cf74a709/Statistiche-Roma',
#  '/it/squadre/922493f3/Statistiche-Atalanta',
#  '/it/squadre/7213da33/Statistiche-Lazio',
#  '/it/squadre/d48ad4ff/Statistiche-Napoli',
#  '/it/squadre/105360fe/Statistiche-Torino',
#  '/it/squadre/421387cf/Statistiche-Fiorentina',
#  '/it/squadre/21680aa4/Statistiche-Monza',
#  '/it/squadre/658bf2de/Statistiche-Genoa',
#  '/it/squadre/ffcbe334/Statistiche-Lecce',
#  '/it/squadre/04eea015/Statistiche-Udinese',
#  '/it/squadre/0e72edf2/Statistiche-Hellas-Verona',
#  '/it/squadre/c4260e09/Statistiche-Cagliari',
#  '/it/squadre/6a7ad59d/Statistiche-Frosinone',
#  '/it/squadre/a3d88bd8/Statistiche-Empoli',
#  '/it/squadre/e2befd26/Statistiche-Sassuolo',
#  '/it/squadre/c5577084/Statistiche-Salernitana']

# %%
team_urls = [f"https://fbref.com{l}" for l in links]
# usiamo il formato stringa per prendere ogni link e collegarlo alla stringa all'inizio del link

# %%
team_urls
# Out:
# ['https://fbref.com/it/squadre/d609edc0/Statistiche-Internazionale',
#  'https://fbref.com/it/squadre/dc56fe14/Statistiche-Milan',
#  'https://fbref.com/it/squadre/e0652b02/Statistiche-Juventus',
#  'https://fbref.com/it/squadre/1d8099f8/Statistiche-Bologna',
#  'https://fbref.com/it/squadre/cf74a709/Statistiche-Roma',
#  'https://fbref.com/it/squadre/922493f3/Statistiche-Atalanta',
#  'https://fbref.com/it/squadre/7213da33/Statistiche-Lazio',
#  'https://fbref.com/it/squadre/d48ad4ff/Statistiche-Napoli',
#  'https://fbref.com/it/squadre/105360fe/Statistiche-Torino',
#  'https://fbref.com/it/squadre/421387cf/Statistiche-Fiorentina',
#  'https://fbref.com/it/squadre/21680aa4/Statistiche-Monza',
#  'https://fbref.com/it/squadre/658bf2de/Statistiche-Genoa',
#  'https://fbref.com/it/squadre/ffcbe334/Statistiche-Lecce',
#  'https://fbref.com/it/squadre/04eea015/Statistiche-Udinese',
#  'https://fbref.com/it/squadre/0e72edf2/Statistiche-Hellas-Verona',
#  'https://fbref.com/it/squadre/c4260e09/Statistiche-Cagliari',
#  'https://fbref.com/it/squadre/6a7ad59d/Statistiche-Frosinone',
#  'https://fbref.com/it/squadre/a3d88bd8/Statistiche-Empoli',
#  'https://fbref.com/it/squadre/e2befd26/Statistiche-Sassuolo',
#  'https://fbref.com/it/squadre/c5577084/Statistiche-Salernitana']

# %% [markdown]
# ### Adesso prendiamo le stastistiche che ci interessano per ogni team

# %%
team_url = team_urls[0]

data = requests.get(team_url)

#a noi interessano le stastistiche della tabella 'punteggi e partite', che ispezionando la pagina
# è la tabella con il tag 'stats table'
# quindi ci interessa tutta la tabella della pagina e renderla un data frame 
#per far cioò utilizziamo la libreria Pandas, utilizzando il metodo 'read_html'

import pandas as pd

#con 'read_html' pandas cercerà su data.text la parola 'Punteggi e partite', che rapressenta la tabella
matches = pd.read_html(data.text, match = "Punteggi e partite")

# %%
matches[0].head()
# Out:
#          Data    Ora  Competizione         Girone Giorno  Stadio Risultato Rf  \
# 0  19-08-2023  20:45       Serie A  Giornata n. 1    Sab    Casa         V  2
# 1  28-08-2023  20:45       Serie A  Giornata n. 2    Lun  Ospiti         V  2
# 2  03-09-2023  18:30       Serie A  Giornata n. 3    Dom    Casa         V  4
# 3  16-09-2023  18:00       Serie A  Giornata n. 4    Sab    Casa         V  5
# 4  20-09-2023  21:00  Champions Lg  Fase a gironi    Mer  Ospiti         N  1
#
#   Rs        Avversario   xG  xGA  Poss.  Spettatori          Capitano  \
# 0  0             Monza  2.7  0.8   47.0      72.509  Lautaro Martínez
# 1  0          Cagliari  0.9  0.6   67.0      16.412  Lautaro Martínez
# 2  0        Fiorentina  3.7  0.4   40.0      72.739  Lautaro Martínez
# 3  1             Milan  2.6  1.1   41.0      75.571  Lautaro Martínez
# 4  1  es Real Sociedad  0.5  1.3   56.0      36.591  Lautaro Martínez
#
#   Formazione           Arbitro  Report partita Note
# 0      3-5-2    Andrea Colombo  Report partita  NaN
# 1      3-5-2    Michael Fabbri  Report partita  NaN
# 2      3-5-2  Matteo Marchetti  Report partita  NaN
# 3      3-5-2      Simone Sozza  Report partita  NaN
# 4      3-5-2    Michael Oliver  Report partita  NaN

# %% [markdown]
# ### Tiri di ogni squadra

# %% [markdown]
# Utilizzando lo stesso procedimento, andiamo a prendere i tiri che ha effettuato ogni squadra

# %%
soup = BeautifulSoup(data.text)

links = soup.find_all('a')

links = [l.get('href') for l in links]

links = [l for l in links if l and 'all_comps/shooting/' in l]

# %%
links
# Out:
# ['/it/squadre/d609edc0/2023-2024/partite/all_comps/shooting/Registri-incontri-Internazionale-Tutte-le-competizioni',
#  '/it/squadre/d609edc0/2023-2024/partite/all_comps/shooting/Registri-incontri-Internazionale-Tutte-le-competizioni',
#  '/it/squadre/d609edc0/2023-2024/partite/all_comps/shooting/Registri-incontri-Internazionale-Tutte-le-competizioni',
#  '/it/squadre/d609edc0/2023-2024/partite/all_comps/shooting/Registri-incontri-Internazionale-Tutte-le-competizioni']

# %%
data = requests.get(f"https://fbref.com{links[0]}")

# %%
shooting = pd.read_html(data.text, match = "Tiri")[0]

shooting.head()
# Out:
#   Di: Internazionale                                                     \
#                 Data    Ora  Competizione         Girone Giorno  Stadio
# 0         19-08-2023  20:45       Serie A  Giornata n. 1    Sab    Casa
# 1         28-08-2023  20:45       Serie A  Giornata n. 2    Lun  Ospiti
# 2         03-09-2023  18:30       Serie A  Giornata n. 3    Dom    Casa
# 3         16-09-2023  18:00       Serie A  Giornata n. 4    Sab    Casa
# 4         20-09-2023  21:00  Champions Lg  Fase a gironi    Mer  Ospiti
#
#                                      ... Standard                    \
#   Risultato Rf Rs        Avversario  ...    Dist. Pun. Rigori Rig T
# 0         V  2  0             Monza  ...    172.0  1.0      0     0
# 1         V  2  0          Cagliari  ...    159.0  0.0      0     0
# 2         V  4  0        Fiorentina  ...    145.0  1.0      1     1
# 3         V  5  1             Milan  ...    152.0  1.0      1     1
# 4         N  1  1  es Real Sociedad  ...    147.0  0.0      0     0
#
#   Prestazione prevista                           Unnamed: 25_level_0
#                     xG npxG npxG/Sh G-xG np:G-xG      Report partita
# 0                  2.7  2.7    12.0 -0.7    -0.7      Report partita
# 1                  0.9  0.9     5.0  1.1     1.1      Report partita
# 2                  3.7  2.9    15.0  0.3     0.1      Report partita
# 3                  2.6  1.8    14.0  2.4     2.2      Report partita
# 4                  0.5  0.5     9.0  0.5     0.5      Report partita
#
# [5 rows x 26 columns]

# %% [markdown]
# #### Puliamo la tabella togliendo le colonne che non ci interessano o che sono vuote

# %%
shooting.columns = shooting.columns.droplevel() #togliamo la prima riga

# %%
shooting.head()
# Out:
#          Data    Ora  Competizione         Girone Giorno  Stadio Risultato Rf  \
# 0  19-08-2023  20:45       Serie A  Giornata n. 1    Sab    Casa         V  2
# 1  28-08-2023  20:45       Serie A  Giornata n. 2    Lun  Ospiti         V  2
# 2  03-09-2023  18:30       Serie A  Giornata n. 3    Dom    Casa         V  4
# 3  16-09-2023  18:00       Serie A  Giornata n. 4    Sab    Casa         V  5
# 4  20-09-2023  21:00  Champions Lg  Fase a gironi    Mer  Ospiti         N  1
#
#   Rs        Avversario  ...  Dist.  Pun.  Rigori  Rig T   xG  npxG  npxG/Sh  \
# 34         V      4      0               Lecce  ...    Lautaro Martínez
# 35         V      4      0            Atalanta  ...    Lautaro Martínez
# 36         V      2      1               Genoa  ...    Lautaro Martínez
# 37         V      1      0             Bologna  ...      Nicolò Barella
# 38         P  1 (2)  2 (3)  es Atlético Madrid  ...    Lautaro Martínez
# 39         N      1      1              Napoli  ...    Lautaro Martínez
# 40         V      2      0              Empoli  ...    Lautaro Martínez
#
#     Formazione             Arbitro  Report partita  \
# 0        3-5-2      Andrea Colombo  Report partita
# 1        3-5-2      Michael Fabbri  Report partita
# 2        3-5-2    Matteo Marchetti  Report partita
# 3        3-5-2        Simone Sozza  Report partita
# 4        3-5-2      Michael Oliver  Report partita
# 5        3-5-2    Matteo Marcenaro  Report partita
# 6        3-5-2        Luca Massimi  Report partita
# 7        3-5-2      Rosario Abisso  Report partita
# 8        3-5-2      Danny Makkelie  Report partita
# 9        3-5-2         Marco Guida  Report partita
# 10       3-5-2    Matteo Marchetti  Report partita
# 11       3-5-2   François Letexier  Report partita
# 12       3-5-2       Fabio Maresca  Report partita
# 13       3-5-2        Simone Sozza  Report partita
# 14       3-5-2    Serdar Gözübüyük  Report partita
# 15       3-5-2    Federico Dionisi  Report partita
# 16       3-5-2         Marco Guida  Report partita
# 17     3-1-4-2    Andris Treimanis  Report partita
# 18       3-5-2        Davide Massa  Report partita
# 19       3-5-2      Marco Di Bello  Report partita
# 20       3-5-2      Sandro Schärer  Report partita
# 21       3-5-2       Fabio Maresca  Report partita
# 22       3-5-2   Federico La Penna  Report partita
# 23       3-5-2    Matteo Marcenaro  Report partita
# 24       3-5-2      Daniele Doveri  Report partita
# 25       3-5-2      Michael Fabbri  Report partita
# 26       3-5-2     Antonio Rapuano  Report partita
# 27       3-5-2    Matteo Marchetti  Report partita
# 28       3-5-2     Antonio Rapuano  Report partita
# 29       3-5-2  Gianluca Aureliano  Report partita
# 30       3-5-2       Fabio Maresca  Report partita
# 31       5-3-2         Marco Guida  Report partita
# 32       3-5-2     Marco Piccinini  Report partita
# 33       3-5-2       István Kovács  Report partita
# 34       3-5-2      Daniele Doveri  Report partita
# 35       3-5-2      Andrea Colombo  Report partita
# 36       3-5-2    Giovanni Ayroldi  Report partita
# 37       3-5-2       Luca Pairetto  Report partita
# 38       3-5-2    Szymon Marciniak  Report partita
# 39       3-5-2   Federico La Penna  Report partita
# 40       3-5-2    Federico Dionisi  Report partita
#
#                                                  Note Tiri  Dist. Pun. Rigori  \
# 0                                                 NaN   22  172.0  1.0      0
# 1                                                 NaN   17  159.0  0.0      0
# 2                                                 NaN   20  145.0  1.0      1
# 3                                                 NaN   13  152.0  1.0      1
# 4                                                 NaN    6  147.0  0.0      0
# 5                                                 NaN   23  168.0  0.0      0
# 6                                                 NaN   13  152.0  0.0      0
# 7                                                 NaN   15  168.0  1.0      1
# 8                                                 NaN   21  143.0  1.0      0
# 9                                                 NaN   14  183.0  1.0      0
# 10                                                NaN   13  171.0  1.0      1
# 11                                                NaN   16  162.0  0.0      1
# 12                                                NaN   19  160.0  0.0      0
# 13                                                NaN    9  230.0  1.0      1
# 14                                                NaN   16  197.0  1.0      1
# 15                                                NaN   20  196.0  1.0      1
# 16                                                NaN    8  164.0  0.0      0
# 17                                                NaN   13  188.0  1.0      1
# 18                                                NaN   11  160.0  0.0      0
# 19                                                NaN   16  167.0  0.0      1
# 20                                                NaN   10  157.0  0.0      0
# 21                                                NaN   12  138.0  1.0      0
# 22                                Tempi supplementari   21    NaN  NaN      0
# 23                                                NaN   20  151.0  1.0      0
# 24                                                NaN   16  144.0  0.0      0
# 25                                                NaN   15  152.0  0.0      0
# 26                                                NaN   18  197.0  1.0      2
# 27                                                NaN   23    NaN  NaN      1
# 28                                                NaN   22    NaN  NaN      0
# 29                                                NaN    8  171.0  0.0      0
# 30                                                NaN   15  154.0  0.0      0
# 31                                                NaN   10  212.0  1.0      0
# 32                                                NaN   26  140.0  1.0      0
# 33                                 Giornata n. 1 di 2   19  163.0  0.0      0
# 34                                                NaN   11  156.0  0.0      0
# 35                                                NaN   14  178.0  0.0      0
# 36                                                NaN   14  179.0  0.0      1
# 37                                                NaN    5  126.0  0.0      0
# 38  Giornata n. 2 di 2; Atlético Madrid qualificat...   15  191.0  1.0      0
# 39                                                NaN   19  155.0  1.0      0
# 40                                                NaN   19  179.0  0.0      0
#
#     Rig T
# 0       0
# 1       0
# 2       1
# 3       1
# 4       0
# 5       0
# 6       0
# 7       1
# 8       0
# 9       0
# 10      1
# 11      1
# 12      0
# 13      1
# 14      1
# 15      1
# 16      0
# 17      1
# 18      0
# 19      1
# 20      0
# 21      0
# 22      1
# 23      0
# 24      0
# 25      0
# 26      2
# 27      1
# 28      0
# 29      0
# 30      0
# 31      0
# 32      0
# 33      0
# 34      0
# 35      1
# 36      1
# 37      0
# 38      0
# 39      0
# 40      0
#
# [41 rows x 24 columns]

# %% [markdown]
# ## Raccolta di dati per più stagioni e squadra con un ciclo

# %% [markdown]
# Combiniamo il codice gia scritto per raccogliere più stagioni e tutte le squadre del campionato, utilizzando un ciclo for

# %%
years = list(range(2024,2022, -1))

# %%
years
# Out:
# [2024, 2023]

# %%
#inizializzo una lista chiamata all_matches che conterrà diversi dataframe. 
#Ogni dataframe conterrà i match logs di un team in una stagione.
#Alla fine combinerermo tutti i dataframe ottenuti in un unico grande dataframe

all_matches = []

# %%
standings_url = "https://fbref.com/it/comp/11/Statistiche-di-Serie-A"

# %%
import time

for year in years:
    data = requests.get(standings_url)
    soup = BeautifulSoup(data.text)
    standings_table = soup.select('table.stats_table')[0]
    
    links = [l.get("href") for l in standings_table.find_all('a')]
    links = [l for l in links if '/squadre/' in l]
    team_urls = [f"https://fbref.com{l}" for l in links]
    
    previous_season = soup.select("a.prev")[0].get("href")
    standings_url = f"https://fbref.com/{previous_season}"
    
    for team_url in team_urls:
        team_name = team_url.split("/")[-1].replace("Statistiche-","").replace("-","")
        #'[-1]'ovvero l'ultimo pezzo del link
        
        data = requests.get(team_url)
        matches = pd.read_html(data.text, match = "Punteggi e partite")[0]
        
        soup = BeautifulSoup(data.text)
        links = [l.get('href') for l in soup.find_all('a')]
        links = [l for l in links if l and 'all_comps/shooting/' in l]
        data = requests.get(f"https://fbref.com{links[0]}")
        shooting = pd.read_html(data.text, match = "Tiri")[0]
        shooting.columns = shooting.columns.droplevel()
        
        #mettiamo un try poichè può capitare che a volte per qualche squadre la statistica del tiro non è disponibile
        #e quando si fa il merge pandas può dare un ValueError poichè la statistiche è vuota
        
        try:
            team_data = matches.merge(shooting[["Data", "Tiri", "Dist.", "Pun.", "Rigori", "Rig T"]], on="Data")
        except ValueError:
            continue
            
        #dividiamo le competizioni (campionato, coppa italia, ...)
        
        team_data = team_data[team_data["Competizione"] == 'Serie A']
        team_data["Stagione"] = year
        team_data["Squadra"]= team_name
        
        all_matches.append(team_data)
        time.sleep(1) #per assicurarci che quando facciamo scraping il website non si blocca a causa delle richieste

# %%
match_df = pd.concat(all_matches)
match_df
# Out:
#           Data    Ora Competizione          Girone Giorno  Stadio Risultato  \
# 0   19-08-2023  20:45      Serie A   Giornata n. 1    Sab    Casa         V
# 1   28-08-2023  20:45      Serie A   Giornata n. 2    Lun  Ospiti         V
# 2   03-09-2023  18:30      Serie A   Giornata n. 3    Dom    Casa         V
# 3   16-09-2023  18:00      Serie A   Giornata n. 4    Sab    Casa         V
# 5   24-09-2023  12:30      Serie A   Giornata n. 5    Dom  Ospiti         V
# ..         ...    ...          ...             ...    ...     ...       ...
# 36  08-05-2023  18:30      Serie A  Giornata n. 34    Lun  Ospiti         P
# 37  15-05-2023  20:45      Serie A  Giornata n. 35    Lun    Casa         N
# 38  20-05-2023  20:45      Serie A  Giornata n. 36    Sab  Ospiti         P
# 39  26-05-2023  20:45      Serie A  Giornata n. 37    Ven    Casa         N
# 40  04-06-2023  18:30      Serie A  Giornata n. 38    Dom  Ospiti         P
#
#    Rf Rs  Avversario  ...               Arbitro  Report partita  Note  Tiri  \
# 0   2  0       Monza  ...        Andrea Colombo  Report partita   NaN  22.0
# 1   2  0    Cagliari  ...        Michael Fabbri  Report partita   NaN  17.0
# 2   4  0  Fiorentina  ...      Matteo Marchetti  Report partita   NaN  20.0
# 3   5  1       Milan  ...          Simone Sozza  Report partita   NaN  13.0
# 5   1  0      Empoli  ...      Matteo Marcenaro  Report partita   NaN  23.0
# .. .. ..         ...  ...                   ...             ...   ...   ...
# 36  0  2     Udinese  ...        Niccolò Baroni  Report partita   NaN  11.0
# 37  1  1      Empoli  ...     Ermanno Feliciani  Report partita   NaN  13.0
# 38  1  5       Milan  ...    Francesco Fourneau  Report partita   NaN   6.0
# 39  2  2    Sassuolo  ...  Francesco Meraviglia  Report partita   NaN  17.0
# 40  0  2      Napoli  ...     Ermanno Feliciani  Report partita   NaN   6.0
#
#     Dist. Pun. Rigori Rig T Stagione         Squadra
# 0   172.0  1.0      0     0     2024  Internazionale
# 1   159.0  0.0      0     0     2024  Internazionale
# 2   145.0  1.0      1     1     2024  Internazionale
# 3   152.0  1.0      1     1     2024  Internazionale
# 5   168.0  0.0      0     0     2024  Internazionale
# ..    ...  ...    ...   ...      ...             ...
# 36  211.0  1.0      0     0     2023       Sampdoria
# 37  165.0  1.0      0     0     2023       Sampdoria
# 38  175.0  0.0      0     0     2023       Sampdoria
# 39  150.0  0.0      0     0     2023       Sampdoria
# 40  106.0  0.0      0     0     2023       Sampdoria
#
# [1360 rows x 26 columns]

# %%
match_df.colums = [c.lower() for c in match_df.columns]
# Out:
# C:\Users\aless\AppData\Local\Temp\ipykernel_3656\3696686760.py:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   match_df.colums = [c.lower() for c in match_df.columns]

# %%
match_df.to_csv("matches.csv") #importiamo il dataframe in un file csv
